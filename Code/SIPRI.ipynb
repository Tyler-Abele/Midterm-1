# %%
import pandas as pd

regional_totals = pd.read_excel('../Data/SIPRI-Milex-data-1949-2025.xlsx', sheet_name='Regional totals', header=13)

regional_totals.head()
# Out:
#                Region         1988         1989         1990        1991  \
# 0               World  1749.513663  1728.656861  1660.735248         ...
# 1              Africa    20.855433    21.216506    21.077700   18.319674
# 2        North Africa     3.446906     3.589976     3.575339    3.697637
# 3  sub-Saharan Africa    17.408527    17.626530    17.502362   14.622037
# 4            Americas   862.529259   853.487763   815.081594  721.208578
#
#           1992         1993         1994         1995         1996  ...  \
# 0  1388.099675  1325.224149  1291.566313  1220.729826  1186.060557  ...
# 1    16.843798    19.301099    26.126246    15.909807    15.054588  ...
# 2     4.206792     4.429040     4.800439     4.576832     4.850587  ...
# 3    12.637005    14.872059    21.325807    11.332975    10.204002  ...
# 4   755.456463   722.241450   690.604064   652.938226   617.257371  ...
#
#           2018         2019         2020         2021         2022  \
# ...

# %%
country_totals_usd = pd.read_excel('../Data/SIPRI-Milex-data-1949-2025.xlsx', sheet_name='Current US$', header=5)

country_totals_usd.head()
# Out:
#         Country  Notes 1949 1950 1951 1952 1953 1954 1955 1956  ...  \
# 0           NaN    NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  ...
# 1        Africa    NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  ...
# 2  North Africa    NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  ...
# 3       Algeria     §4  ...  ...  ...  ...  ...  ...  ...  ...  ...
# 4         Libya  ‡§¶16  ...  ...  ...  ...  ...  ...  ...  ...  ...
#
#            2015        2016          2017         2018          2019  \
# 0           NaN         NaN           NaN          NaN           NaN
# 1           NaN         NaN           NaN          NaN           NaN
# 2           NaN         NaN           NaN          NaN           NaN
# 3  10407.345244  10217.0817  10073.364021  9583.724288  10303.600575
# 4           ...         ...           ...          ...           ...
#
#          2020         2021         2022          2023          2024
# 0         NaN          NaN          NaN           NaN           NaN
# ...

# %%
share_of_gdp = pd.read_excel('../Data/SIPRI-Milex-data-1949-2025.xlsx', sheet_name='Share of GDP', header=5)

share_of_gdp.head()
# Out:
#         Country  Notes 1949 1950 1951 1952 1953 1954 1955 1956  ...      2015  \
# 0           NaN    NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  ...       NaN
# 1        Africa    NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  ...       NaN
# 2  North Africa    NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  ...       NaN
# 3       Algeria     §4  ...  ...  ...  ...  ...  ...  ...  ...  ...  0.055507
# 4         Libya  ‡§¶16  ...  ...  ...  ...  ...  ...  ...  ...  ...       ...
#
#        2016      2017      2018     2019      2020    2021      2022  \
# 0       NaN       NaN       NaN      NaN       NaN     NaN       NaN
# 1       NaN       NaN       NaN      NaN       NaN     NaN       NaN
# 2       NaN       NaN       NaN      NaN       NaN     NaN       NaN
# 3  0.056527  0.053071  0.049299  0.05327  0.058861  0.0489  0.040575
# 4       ...       ...       ...      ...       ...     ...  0.043467
#
#        2023      2024
# 0       NaN       NaN
# 1       NaN       NaN
# ...

# %%
per_capita = pd.read_excel('../Data/SIPRI-Milex-data-1949-2025.xlsx', sheet_name='Per capita', header=6)

per_capita.head()
# Out:
#         Country  Notes       1988       1989       1990       1991       1992  \
# 0        Africa    NaN        NaN        NaN        NaN        NaN        NaN
# 1  North Africa    NaN        NaN        NaN        NaN        NaN        NaN
# 2       Algeria     §4  43.257136   34.95503   36.07121  22.002806  40.060155
# 3         Libya  ‡§¶16        ...        ...        ...        ...        ...
# 4       Morocco    §17  39.403288  41.756812  44.282009  46.696174  49.133201
#
#         1993       1994       1995  ...        2015        2016        2017  \
# 0        NaN        NaN        NaN  ...         NaN         NaN         NaN
# 1        NaN        NaN        NaN  ...         NaN         NaN         NaN
# 2  47.356145  48.383894    43.8054  ...  262.745399  252.716656  244.072592
# 3        ...        ...        ...  ...         ...         ...         ...
# 4  49.242222  52.900264  54.894201  ...   94.985712   95.587884   98.222568
#
# ...
