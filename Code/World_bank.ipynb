# %%
import pandas as pd

cur = pd.read_excel('../Data/Class_2025_10_07.xlsx')
cur.head()
# Out:
#           Economy Code                                             Region  \
# 0     Afghanistan  AFG  Middle East, North Africa, Afghanistan & Pakistan
# 1         Albania  ALB                              Europe & Central Asia
# 2         Algeria  DZA  Middle East, North Africa, Afghanistan & Pakistan
# 3  American Samoa  ASM                                East Asia & Pacific
# 4         Andorra  AND                              Europe & Central Asia
#
#           Income group Lending category
# 0           Low income              IDA
# 1  Upper middle income             IBRD
# 2  Upper middle income             IBRD
# 3          High income              NaN
# 4          High income              NaN

# %%
# historic data

hist = pd.read_excel('../Data/World_bank_hist.xlsx')
hist.head()
# Out:
#        Unnamed: 0 Unnamed: 1 Unnamed: 2 Unnamed: 3 Unnamed: 4 Unnamed: 5  \
# 0         Country       FY89       FY90       FY91       FY92       FY93
# 1     Afghanistan          L          L          L          L          L
# 2         Albania         ..         ..         ..         LM         LM
# 3         Algeria         UM         UM         LM         LM         LM
# 4  American Samoa          H          H          H         UM         UM
#
#   Unnamed: 6 Unnamed: 7 Unnamed: 8 Unnamed: 9  ... Unnamed: 29 Unnamed: 30  \
# 0       FY94       FY95       FY96       FY97  ...        FY17        FY18
# 1          L          L          L          L  ...           L           L
# 2         LM          L          L          L  ...          UM          UM
# 3         LM         LM         LM         LM  ...          UM          UM
# 4         UM         UM         UM         UM  ...          UM          UM
#
# ...
